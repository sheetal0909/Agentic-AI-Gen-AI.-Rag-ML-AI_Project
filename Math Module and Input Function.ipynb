# %% [markdown]
# Day 08/13/2026 Class  * Math Module *

# %%
sqrt(25)  #got an error

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
math.floor(3.5)  #floor and Ceil Function
# Out:
# 3

# %%
math.ceil(3.5)
# Out:
# 4

# %%
math.floor(5.9)
# Out:
# 5

# %%
math.ceil(5.9)
# Out:
# 6

# %%
math.pow(3,3)
# Out:
# 27.0

# %%
import math as s 
print(s.pow(5,3))
print(s.sqrt(49))
print(s.floor(4.9))
print(s.ceil(4.9))
print(s.sqrt(36))
print(s.pow(5,2))
# Out:
# 125.0
# 7.0
# 4
# 5
# 6.0
# 25.0

# %%
from math import pow, floor, ceil, sqrt
print(pow(5,3))
print(sqrt(49))
print(floor(4.9))
print(ceil(4.9))
print(sqrt(36))
print(pow(5,2))
# Out:
# 125.0
# 7.0
# 4
# 5
# 6.0
# 25.0

# %%
#help()

# %%
from math import *  # (* - select all inbuild functiom)
print(pow(5,3))
print(sqrt(49))
print(floor(4.9))
print(ceil(4.9))
print(sqrt(36))
print(pow(5,2))
# Out:
# 125.0
# 7.0
# 4
# 5
# 6.0
# 25.0

# %% [markdown]
#  Input function

# %%
x = input()
x
# Out:
#  3
# '3'

# %%
x = input()   # input() function always reads the input as a string. That’s why when we use + Python performs concatenation (joining the strings) instead of addition.
y = input()
z = x+y
print(z)
# Out:
#  3
#  5
# 35

# %%
x = int(input('Enter the first number'))   # Converting a string to integer (number) using int keywoerd
y = int(input('Enter the second number'))
z = x+y
print(z)
# Out:
# Enter the firts number 12
# Enter the second number 11
# 23

# %%
st = input('enter a string')[5:]
print(st)
# Out:
# enter a string 123456789012
# 6789012

# %%
st = input('enter a string')
print(st)
# Out:
# enter a string sheetal
# sheetal

# %% [raw]
# s = input('Enter First Name ')
# s1 = input('Enter Last Name')
# fl =s+s1
# print(fl)

# %%
result = eval(input( 'Enter an expression')) # Eval keyword is used for an expression
print(result)
# Out:
# Enter an expression 2+8*3+4-5
# 25
