# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.3

# %%
df = pd.read_excel(r'C:\Users\sheet\Desktop\Full Stack Data Science\data.xlsx')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
len(df)
# Out:
# 195

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
len(df.columns)
# Out:
# 5

# %%
df.shape# Dimension of the table(no.of rows and columns)
# Out:
# (195, 5)

# %%
df.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    str
#  1   CountryCode    195 non-null    str
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    str
# dtypes: float64(2), str(3)
# memory usage: 12.9 KB

# %%
df.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
df[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[::3]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244        78.9000
# 3                           Albania         ALB     12.877        57.2000
# 6                           Armenia         ARM     13.308        41.9000
# 9                           Austria         AUT      9.400        80.6188
# 12                          Belgium         BEL     11.200        82.1702
# ..                              ...         ...        ...            ...
# 180                         Uruguay         URY     14.374        57.6900
# 183  St. Vincent and the Grenadines         VCT     16.306        52.0000
# 186                         Vietnam         VNM     15.537        43.9000
# 189                           Samoa         WSM     26.172        15.3000
# 192                Congo, Dem. Rep.         COD     42.394         2.2000
#
#              IncomeGroup
# 0            High income
# 3    Upper middle income
# ...

# %%
df[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
df[10:21]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# 13                   Benin         BEN     36.440        4.90000
# 14            Burkina Faso         BFA     40.551        9.10000
# 15              Bangladesh         BGD     20.142        6.63000
# 16                Bulgaria         BGR      9.200       53.06150
# 17                 Bahrain         BHR     15.040       90.00004
# 18            Bahamas, The         BHS     15.339       72.00000
# 19  Bosnia and Herzegovina         BIH      9.062       57.79000
# 20                 Belarus         BLR     12.500       54.17000
#
#             IncomeGroup
# 10  Upper middle income
# 11           Low income
# 12          High income
# 13           Low income
# 14           Low income
# 15  Lower middle income
# ...

# %%
df[10:150:20]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 110      Moldova         MDA     12.141      45.000000  Lower middle income
# 130  Netherlands         NLD     10.200      93.956400          High income

# %%
df[::10]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
df[::-50]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 194          Zimbabwe         ZWE     35.715        18.5000
# 144  French Polynesia         PYF     16.393        56.8000
# 94           Kiribati         KIR     29.044        11.5000
# 44     Czech Republic         CZE     10.200        74.1104
#
#              IncomeGroup
# 194           Low income
# 144          High income
# 94   Lower middle income
# 44           High income

# %%
df.head(3)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income

# %%
df['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: str

# %%
df_cat= df[['CountryName', 'CountryCode', 'IncomeGroup']]
print(df_cat)
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
df_num = df[['BirthRate', 'InternetUsers']]
print(df_num)
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
print(len(df.columns))
print(len(df_cat.columns))
print(len(df_num.columns))
# Out:
# 5
# 3
# 2

# %%
print(df.shape)
print(df_cat.shape)
print(df_num.shape)
# Out:
# (195, 5)
# (195, 3)
# (195, 2)

# %%
df.describe()  # Descriptive Statistic
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_cat.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
df.BirthRate*df.InternetUsers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
df['MyCal'] = df.BirthRate*df.InternetUsers
df.MyCal
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Name: MyCal, Length: 195, dtype: float64

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'MyCal'],
#       dtype='str')

# %%
len(df.columns)
# Out:
# 6

# %%
df = df.drop('MyCal',axis = 1) # axis--0 represent Records ,axis ---1 represents columns drop is nothing delate

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
len(df.columns)
# Out:
# 5

# %%
df.columns = ['a','b','c','d','e']   #Renamimg the columns
df.head(1)
# Out:
#        a    b       c     d            e
# 0  Aruba  ABW  10.244  78.9  High income

# %%
df.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.InternetUsers < 3
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[df['InternetUsers'] < 3
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 11            Burundi         BDI     44.151            1.3
# 52            Eritrea         ERI     34.800            0.9
# 55           Ethiopia         ETH     32.925            1.9
# 64             Guinea         GIN     37.337            1.6
# 117           Myanmar         MMR     18.119            1.6
# 127             Niger         NER     49.661            1.7
# 154      Sierra Leone         SLE     36.729            1.7
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 172       Timor-Leste         TLS     35.755            1.1
# 192  Congo, Dem. Rep.         COD     42.394            2.2
#
#              IncomeGroup
# 11            Low income
# 52            Low income
# 55            Low income
# 64            Low income
# 117  Lower middle income
# 127           Low income
# 154           Low income
# 156           Low income
# ...

# %%
len(df[df['InternetUsers'] < 3])
# Out:
# 11

# %%
df[df['BirthRate'] > 40]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
len(df[df['BirthRate'] > 40])
# Out:
# 12

# %%
df[(df.BirthRate> 40) & (df.InternetUsers> 2)]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 128           Nigeria         NGA     40.045           38.0
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 14            Low income
# 65            Low income
# 115           Low income
# 128  Lower middle income
# 167           Low income
# 178           Low income
# 192           Low income
# 193  Lower middle income

# %%
len(df[(df.BirthRate> 40) & (df.InternetUsers> 2)])
# Out:
# 9

# %%
df.IncomeGroup.unique()
# Out:
# <ArrowStringArray>
# ['High income', 'Low income', 'Upper middle income', 'Lower middle income']
# Length: 4, dtype: str

# %%
df.IncomeGroup.nunique()
# Out:
# 4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] =6,2

import warnings
warnings.filterwarnings('ignore')  #as error

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df.InternetUsers
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
visual1 = sns.distplot(df["InternetUsers"])

# %%
visual2 = sns.displot(df["InternetUsers"], bins = 10)  # Univariate analysis  - plot the grapgh using one variable

# %%
#visual4 = sns.boxplot(data = df,x = "InternetUsers",  y = "BirthRate")
#Boxclot
visual4 = sns.boxplot(data=df, x="InternetUsers", y="BirthRate")

# %%
#Linear model plot
visual4 = sns.lmplot(data=df, x="InternetUsers", y="BirthRate")

# %%
#Linear model plot
visual4 = sns.lmplot(data=df, x="InternetUsers", y="BirthRate" ,fit_reg=False)

# %%
#Linear model plot
visual4 = sns.lmplot(data=df, x="InternetUsers", y="BirthRate" ,fit_reg=True)

# %%
visual4 = sns.lmplot(data=df, x="InternetUsers", y="BirthRate" ,
                     fit_reg=False,hue="IncomeGroup")

# %%
visual4 = sns.lmplot(data=df, x="InternetUsers", y="BirthRate" ,
                     fit_reg=True,hue="IncomeGroup")
