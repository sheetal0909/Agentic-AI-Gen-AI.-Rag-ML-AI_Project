# %% [markdown]
# Python Type Casting

# %% [markdown]
# Intger:-All Other datetype Float,Boolean,Number String to int possible except complex & text string

# %%
127.8
# Out:
# 127.8

# %%
int(127.8) #Converting Float to Integer
# Out:
# 127

# %%
int(True) # Casting Boolean to Integer
# Out:
# 1

# %% [markdown]
# Float:- All Other datetype Integer,Boolean,Number String to Float possible except complex & text string

# %%
float(15)
# Out:
# 15.0

# %%
float(True)
# Out:
# 1.0

# %%
float('15')
# Out:
# 15.0

# %% [markdown]
# All Other DataType to Boolean (Non Zero Arguments True ,Zero Arguments  and Empty False)

# %%
bool(3)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2.7)
# Out:
# True

# %%
bool(-1)
# Out:
# True

# %%
bool(2+3j)
# Out:
# True

# %%
bool('5')
# Out:
# True

# %%
bool('Five')
# Out:
# True

# %%
bool() # Empty Space would give the False Output
# Out:
# False

# %% [markdown]
#  All Other Datatype to Complex

# %%
complex(3)
# Out:
# (3+0j)

# %%
complex(3.5)
# Out:
# (3.5+0j)

# %%
complex(3.2)
# Out:
# (3.2+0j)

# %%
complex(2.3,3.4)
# Out:
# (2.3+3.4j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('15') #one string number possible
# Out:
# (15+0j)

# %%
complex('-1.3')
# Out:
# (-1.3+0j)

# %% [markdown]
#  All Other Datatype to String it is possible with all possibilities

# %%
str(10)
# Out:
# '10'

# %%
str(1.3)
# Out:
# '1.3'

# %%
str(True)
# Out:
# 'True'

# %%
str(7+3j)
# Out:
# '(7+3j)'

# %%
str(-3)
# Out:
# '-3'
