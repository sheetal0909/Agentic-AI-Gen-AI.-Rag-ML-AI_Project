# %% [markdown]
# Python Varibles

# %%
v = 7
v
# Out:
# 7

# %%
import keyword
keyword.kwlist # All words start with small letter case sensitive except Boolean variable TRUE , False and None
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
keylist = len(keyword.kwlist) #lenght of the list
print("The lenght of the keywords in the list" ,keylist)
# Out:
# The lenght of the keywords in the list 35

# %%
print(15 + 5)
print(15 - 5)
print(20 * 5)
print(25 / 5)
print(10 // 5)
# Out:
# 20
# 10
# 100
# 5.0
# 2

# %% [markdown]
# Integer Variable

# %%
i=5
print(i)
print(type(i))
print(id(i))
# Out:
# 5
# <class 'int'>
# 140722662073592

# %%
age = 35
print(age)
print(type(age))
print(id(age))
# Out:
# 35
# <class 'int'>
# 140722662074552

# %% [markdown]
# Float Variable

# %%
f=9.8
print(f)
print(type(f))
print(id(f))
# Out:
# 9.8
# <class 'float'>
# 1505259299376

# %%
print(i)
print(f)
# Out:
# 5
# 9.8

# %% [markdown]
# Boolean

# %%
b = False
print(b)
type(b)
# Out:
# False
# bool

# %%
c = True
print(c)
type(c)
# Out:
# True
# bool

# %%
b
# Out:
# False

# %%
c
# Out:
# True

# %%
print(True + False)
print(b + c)
# Out:
# 1
# 1

# %%
print(True * False)
print(b * c)
# Out:
# 0
# 0

# %%
print(False * True)
print(c * b)
# Out:
# 0
# 0

# %%
print(False / True)
print(False // True)
# Out:
# 0.0
# 0

# %%
r = 10
s = 10
r,s = 10,10
print(r)
print(s)
# Out:
# 10
# 10

# %%
print(id(r))
print(id(s))
# Out:
# 140722662073752
# 140722662073752

# %%
r = 10
s = s + 15
print(r)
print(s)
print(id(r))
print(id(s))
# Out:
# 10
# 25
# 140722662073752
# 140722662074232

# %% [markdown]
# Complex Datatype

# %%
c = 15 + 25j
print(c)
type(c)  #Capital also allowed J or j
# Out:
# (15+25j)
# complex

# %%
c1 = 17 + 20J
print(c1)
type(c1)
# Out:
# (17+20j)
# complex

# %%
print(c.real)
print(c.imag)
print(c1.real)
print(c1.imag)
# Out:
# 15.0
# 25.0
# 17.0
# 20.0

# %%
c2 = c + c1
print(c2)
print(c2+10)
print(c2+10j)
# Out:
# (32+45j)
# (42+45j)
# (32+55j)

# %% [markdown]
#  String Variables

# %% [markdown]
# Varible Assignment

# %%
intvar = 34 # Integer variable 
floatvar = 6.78 # Float Variable 
strvar = "Apex Language" # String variable 
print(intvar) 
print(floatvar) 
print(strvar)
# Out:
# 34
# 6.78
# Apex Language

# %% [markdown]
# Variables Assignment (Employee Information)

# %%
first_name = 'Sheetal'
last_name = 'Rathod'
country = 'USA'
city = 'Boston'
age = 34
is_married = True
skills = ['Salesforce', 'VisualForce', 'Python', 'HTML', 'SQL']
Employee_info = {
    'firstname':'Sheetal', 
    'lastname':'Rathod', 
    'country':'USA',
    'city':'Boston'
    }
print('First name:', first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Married: ', is_married)
print('Skills: ', skills)
print('Employee Information ', Employee_info)
# Out:
# First name: Sheetal
# First name length: 7
# Last name:  Rathod
# Last name length:  6
# Country:  USA
# City:  Boston
# Age:  34
# Married:  True
# Skills:  ['Salesforce', 'VisualForce', 'Python', 'HTML', 'SQL']
# Employee Information  {'firstname': 'Sheetal', 'lastname': 'Rathod', 'country': 'USA', 'city': 'Boston'}

# %%
first_name, last_name, country, age, is_married = 'Sheetal', 'Rathod', 'USA', 34, True # Declaring multiple variables in one line
print(first_name, last_name, country, age, is_married)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_married)
# Out:
# Sheetal Rathod USA 34 True
# First name: Sheetal
# Last name:  Rathod
# Country:  USA
# Age:  34
# Married:  True

# %% [markdown]
# String concatenation

# %%
First_Name = "Sheetal " 
Last_Name = "Rathod" 
Full_Name = First_Name + Last_Name 
print(Full_Name)
# Out:
# Sheetal Rathod

# %%
s = 'SheetalRathod'
s1 = "Nayak"
print(s)
print(s1)
# Out:
# SheetalRathod
# Nayak

# %% [markdown]
#  String Indexes and Slicing( Forward and backward in String Concept)

# %%
print(s[3])
print(s1[-4])
print(s[:]) # it prints all the values
print(s[8:16])
print(s1[0:6])
print(s[9:-1])
print(s[8:])
print(s[:-1])
print(s1[:2])
print(s[0:14:2]) #Step slicing
print(s[::3]) # Advance slicing
print(s[::-1]) # Reverse Slicing
print(s[::-3])
# Out:
# e
# a
# SheetalRathod
# athod
# Nayak
# tho
# athod
# SheetalRatho
# Na
# Setlahd
# Seltd
# dohtaRlateehS
# dtleS
