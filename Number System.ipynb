# %% [markdown]
# Number System

# %%
bin(15) # Converted Number to Binary System
# Out:
# '0b1111'

# %%
int(0b100001) # Converted Binary to Integer
# Out:
# 33

# %%
oct(45) # Converted Number to Octal
# Out:
# '0o55'

# %%
int(0o130) # Converted Octal to Nmber
# Out:
# 88

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(2)
# Out:
# '0x2'

# %%
int(0x8)
# Out:
# 8

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(16)  # Converted number to Hexadecimal
# Out:
# '0x10'

# %%
int(0x11)
# Out:
# 17

# %%
int(0x19)  # Converted Hexadecimal to Number
# Out:
# 25

# %% [markdown]
# BITWISE Operator

# %%
~12   # Complement
# Out:
# -13

# %%
12&13
# Out:
# 12

# %%
12|13
# Out:
# 13

# %%
12^13
# Out:
# 1

# %%
12<<2 # in left shift we gain the bits ->it means add two zeros to the Bit number 1100 add 2 bits (00) 110000 = 48
# Out:
# 48

# %%
12<<1
# Out:
# 24

# %%
12>>2 # in Right Shift we lose the bits it means 1100 -> 11
# Out:
# 3

# %%
i , j = 5, 6
print(i)
print(j)
# Out:
# 5
# 6

# %%
temp = i # swap two varible using thirrd varible
i = j
j = temp
print(i)
print(j)
# Out:
# 6
# 5

# %%
i, j = 5, 6  #Swap two varible  without third variable
i, j = j, i
print(i)
print(j)
# Out:
# 6
# 5
