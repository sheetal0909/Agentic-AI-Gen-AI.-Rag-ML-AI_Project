# %%
# %pip install matplotlib
# Out:
# Collecting matplotlibNote: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Python310\\share'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 21.2.4; however, version 26.2.1 is available.
# You should consider upgrading via the 'c:\Python310\python.exe -m pip install --upgrade pip' command.
#   Downloading matplotlib-3.10.9-cp310-cp310-win_amd64.whl (8.2 MB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Collecting pillow>=8
#   Using cached pillow-12.3.0-cp310-cp310-win_amd64.whl (7.2 MB)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\sheet\appdata\roaming\python\python310\site-packages (from matplotlib) (26.3)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.5.1-cp310-cp310-win_amd64.whl (70 kB)
# Requirement already satisfied: numpy>=1.23 in c:\python310\lib\site-packages (from matplotlib) (2.2.6)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.64.0-cp310-cp310-win_amd64.whl (1.6 MB)
# Collecting pyparsing>=3
#   Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sheet\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sheet\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(8, 4))
plt.plot(x, y, label="sin(x)", color="blue")
plt.title("Sine Function")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       4 x = np.linspace(0, 10, 100)
#       5 y = np.sin(x)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(8, 4))
plt.plot(x, y, label="sin(x)", color="blue")
plt.title("Sine Function")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       4 x = np.linspace(0, 10, 100)
#       5 y = np.sin(x)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import matplotlib
#       2 print(matplotlib.__version__)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.9-cp310-cp310-win_amd64.whl (8.2 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Requirement already satisfied: pyparsing>=3 in c:\python310\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sheet\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sheet\appdata\roaming\python\python310\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: numpy>=1.23 in c:\python310\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: pillow>=8 in c:\python310\lib\site-packages (from matplotlib) (12.3.0)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python310\lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\sheet\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 matplotlib-3.10.9
# WARNING: You are using pip version 21.2.4; however, version 26.2.1 is available.
# You should consider upgrading via the 'c:\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(8, 4))
plt.plot(x, y, label="sin(x)", color="blue")
plt.title("Sine Function")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.legend()
plt.show()

# %%
#bar chat

cities = ['Delhi', 'Mumbai', 'Bangalore', 'Chennai']
population = [18, 20, 12, 8]

plt.figure(figsize=(6,4))
plt.bar(cities, population, color='green')
plt.title("Population of Cities (in millions)")
plt.xlabel("Cities")
plt.ylabel("Population")
plt.show()

# %%
#pie chart
labels = ['Sleep', 'Work', 'Exercise', 'Leisure', 'Others']
sizes = [8, 9, 2, 3, 2]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0']

plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title("Daily Time Allocation")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
#histogarm
scores = np.random.normal(loc=70, scale=10, size=1000)

plt.figure(figsize=(8,4))
plt.hist(scores, bins=30, color='skyblue', edgecolor='black')
plt.title("Exam Score Distribution")
plt.xlabel("Score")
plt.ylabel("Number of Students")
plt.grid(True)
plt.show()

# %%
#heatmap
data = np.random.rand(10, 10)

plt.figure(figsize=(6, 5))
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.colorbar(label='Value')
plt.title("Random Heatmap")
plt.show()
