# %% [markdown]
#  # List DataStructure

# %%
l = [] # Empty List
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
l.append(20)
l
# Out:
# [20]

# %%
len(l)
# Out:
# 1

# %%
l.append(10)
l.append(30)
l.append(20)
l.append(40)
l.append(50)
l.append(60)
l
# Out:
# [20, 10, 30, 20, 40, 50, 60]

# %%
len(l)
# Out:
# 7

# %%
l1 = [3, 3.5, True, 3+4j, 'Welcome']
l1
# Out:
# [3, 3.5, True, (3+4j), 'Welcome']

# %%
l1.append([2,3,4]) #Nested List
l1
# Out:
# [3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
print(l)
print(l1)
# Out:
# [20, 10, 30, 20, 40, 50, 60]
# [3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
l3 = l.copy()
l3
# Out:
# [20, 10, 30, 20, 40, 50, 60]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [20, 10, 30, 20, 40, 50, 60]
# [3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]
# [20, 10, 30, 20, 40, 50, 60]

# %%
len(l) == len(l3)
# Out:
# True

# %%
print(id(l))
print(id(l3))
# Out:
# 2655198458432
# 2655195069376

# %%
print(l)
print(l1)
print(l3)
# Out:
# [20, 10, 30, 20, 40, 50, 60]
# [3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]
# [20, 10, 30, 20, 40, 50, 60]

# %%
l3.clear()

# %%
print(l)
print(l1)
print(l3)
# Out:
# [20, 10, 30, 20, 40, 50, 60]
# [3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]
# []

# %%
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
print(l)
print(l1)
# Out:
# [20, 10, 30, 20, 40, 50, 60]
# [3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
l.count(10)
# Out:
# 1

# %%
l.count(20)
# Out:
# 2

# %%
print(l)
print(l1)
# Out:
# [20, 10, 30, 20, 40, 50, 60]
# [3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
l.extend(l1)
l
# Out:
# [20, 10, 30, 20, 40, 50, 60, 3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
print(l)
print(l1)
# Out:
# [20, 10, 30, 20, 40, 50, 60, 3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]
# [3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
l.index(40)
# Out:
# 4

# %%
l.index(30)
# Out:
# 2

# %%
l.index(20)
# Out:
# 0

# %%
l[:]
# Out:
# [20, 10, 30, 20, 40, 50, 60, 3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
l[3:]
# Out:
# [20, 40, 50, 60, 3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
l[6]
# Out:
# 60

# %%
l[:3]
# Out:
# [20, 10, 30]

# %%
l[3::]
# Out:
# [20, 40, 50, 60, 3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
l[::3]
# Out:
# [20, 20, 60, True, [2, 3, 4]]

# %%
l[0:5:3]
# Out:
# [20, 20]

# %%
l1[-3]
# Out:
# (3+4j)

# %%
l1
# Out:
# [3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
l1[::-3]
# Out:
# [[2, 3, 4], True]

# %%
l1[4]
# Out:
# 'Welcome'

# %%
print(l1[4][0]) # Nested Indexing
print(l1[4][1])
print(l1[4][2])
print(l1[4][3])
print(l1[4][4])
print(l1[4][5])
print(l1[4][6])
# Out:
# W
# e
# l
# c
# o
# m
# e

# %%
l1
# Out:
# [3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
l1[0] = 3000  # Mutable or Changable 
l1[3] = 1500
l1
# Out:
# [3000, 3.5, True, 1500, 'Welcome', [2, 3, 4]]

# %%
print(l)
print(l1)
# Out:
# [20, 10, 30, 20, 40, 50, 60, 3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]
# [3000, 3.5, True, 1500, 'Welcome', [2, 3, 4]]

# %%
l2 = [20,30,40]
l2
# Out:
# [20, 30, 40]

# %%
l2.insert(2,35)
l2
# Out:
# [20, 30, 35, 40]

# %%
l2.insert(3,[3,4,5]) # insert() only adds one value at a time and adds the value before a specific index, while append() adds the value at the end.
l2
# Out:
# [20, 30, 35, [3, 4, 5], 40]

# %%
l2.pop() # Without arg it deteles last value
# Out:
# 40

# %%
l2
# Out:
# [20, 30, 35, [3, 4, 5]]

# %%
l
# Out:
# [20, 10, 30, 20, 40, 50, 60, 3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
l.pop(2) #Removes values based on their index
# Out:
# 30

# %%
l
# Out:
# [20, 10, 20, 40, 50, 60, 3, 3.5, True, (3+4j), 'Welcome', [2, 3, 4]]

# %%
l.remove(3+4j) # Remove function directly remove the value

# %%
l
# Out:
# [20, 10, 20, 40, 50, 60, 3, 3.5, True, 'Welcome', [2, 3, 4]]

# %%
l.reverse()

# %%
l
# Out:
# [[2, 3, 4], 'Welcome', True, 3.5, 3, 60, 50, 40, 20, 10, 20]

# %%
l[::-1] # Reversing a list using the slice function.
# Out:
# [20, 10, 20, 40, 50, 60, 3, 3.5, True, 'Welcome', [2, 3, 4]]

# %%
l5 = [3, 5,15, 17, 7, 11, 21]

# %%
l5.sort() # By default it sorts in ascending order. and sort() applies only to similar data types.

# %%
l5
# Out:
# [3, 5, 7, 11, 15, 17, 21]

# %%
5 in l5  # Memeber of the list l5
# Out:
# True

# %%
23 in l5
# Out:
# False

# %%
for i in l5:
    print(i)
# Out:
# 3
# 5
# 7
# 11
# 15
# 17
# 21

# %%
for i in enumerate(l5):  #enumerate() generates index numbers.
    print(i)
# Out:
# (0, 3)
# (1, 5)
# (2, 7)
# (3, 11)
# (4, 15)
# (5, 17)
# (6, 21)

# %%
l5
# Out:
# [3, 5, 7, 11, 15, 17, 21]

# %%
all(l5)
# Out:
# True

# %%
any(l5)
# Out:
# True

# %%
l5.append(0)
l5
# Out:
# [3, 5, 7, 11, 15, 17, 21, 0]

# %%
all(l5)  #If the list has zero values then it will print False.If not, it displays True
# Out:
# False

# %%
any(l5)
# Out:
# True

# %% [markdown]
# Tuple Function #Tuples are mainly used to store information that should not be changed, removed, or edited.

# %%
t =()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1 = (3, 5, True , 1+3j, 'Python')
t1
# Out:
# (3, 5, True, (1+3j), 'Python')

# %%
t1[3]
# Out:
# (1+3j)

# %%
t1[:3]
# Out:
# (3, 5, True)

# %%
t1[:-1]
# Out:
# (3, 5, True, (1+3j))

# %%
t1[::-1]
# Out:
# ('Python', (1+3j), True, 5, 3)

# %%
t1
# Out:
# (3, 5, True, (1+3j), 'Python')

# %%
t1.count(5)
# Out:
# 1

# %%
t1.index('Python')
# Out:
# 4

# %%
t = ( 10, 30, 50, 70, 110)
t
# Out:
# (10, 30, 50, 70, 110)

# %%
tup = () # Empty Tuple
tup
# Out:
# ()

# %%
tup1 = (10, 30, 5.6, 'one', 'two', (50,'python',5.4),(25,35)) # Nested Tuple and Different Data Types
tup1
# Out:
# (10, 30, 5.6, 'one', 'two', (50, 'python', 5.4), (25, 35))

# %%
len(tup1)
# Out:
# 7

# %%
tup1[3]
# Out:
# 'one'

# %%
tup1[0]
# Out:
# 10
